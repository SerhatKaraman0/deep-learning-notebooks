# %% [markdown]
# # ANNs
# - ![image.png](attachment:image.png)

# %% [markdown]
# - xi are the independent variables like age, height etc. wi are the importance of these variables. We sum multiply and sum features and variables then add a bias
# - This value we have get sent to an activation function which makes the final decision about the data. If this is a classification task a activation function like sigmoid can decide whether the data belongs to class A or B or 1 or 0 etc.
#
# ## Gradient Descent
# - Minimizing loss
# ![image.png](attachment:image.png)

# %% [markdown]
# - reLU activation function generally used on the activation layer since it has the ability to kill the neuron if it isn't used. and Sigmoid function generally used in the output layer.
#
# ## Forward Propagation
# ![image.png](attachment:image.png)
# - we are simply calculating with initial weights and biases and after that we get the final results then we find our error using mse or log loss whatever is appropiate for the work
# ## Backpropagation
# - After forward propagation we want to optimize the initial weight to make a better model in terms of accuracy and loss / error.
# - Uses Gradient Descent for this job.
# ## Activation Functions Use Cases
# - ReLu    -> In the hidden layers of the model
# - Sigmoid -> Binary classification tasks in the output layer
# - SOftmax -> Multiclass classification tasks in the output layer
# ## Overfitting
# - Early Stopping
# - L1 L2 Regularization
# - Dropout
# - Data Augmentation
